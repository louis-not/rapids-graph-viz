# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '4'
os.environ['BOKEH_ALLOW_WS_ORIGIN'] = 'llm-interface-2-api.legit-ai.co.id'

# %% [markdown]
# # Tested Visualization: Bokeh + CuXFilter

# %%
import json
import cudf
import cugraph
import cuxfilter

# %% [markdown]
# ## Preprocess Sample Data

# %%
DATAPATH = '../sample_data/sample-data-crawler-twt.json'

with open(DATAPATH, 'r') as f:
    raw_data = json.load(f)

print(f"Loaded {len(raw_data)} rows")
print(f"Sample: {raw_data[5]}")
# Out:
# Loaded 211 rows
# Sample: {'id': '1828256366173266411', 'user_screen_name': 'PambinyaTaehyun', 'user_followers_count': 19, 'user_friends_count': 68, 'user_created_at': '2019-10-07T09:21:27+00:00', 'user_status_count': 14661, 'user_is_verified': False, 'user_description': 'genre idup: komedi tragedi', 'user_media_count': 183, 'text': '@ardisatriawan Bjir dah nyampe ranah internasional', 'post_created_at': '2024-08-27T02:20:59+00:00', 'views_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'is_retweeted': False, 'entities_hashtag': [], 'entities_mentions': ['#ardisatriawan'], 'in_quote_username': '', 'in_quote_id': '-', 'in_reply_username': 'ardisatriawan', 'in_reply_id': '1828253940003283240', 'media_urls': [], 'created_at': '2024-12-11T11:24:02.816745', 'updated_at': '2024-12-11T11:24:02.816745'}

# %%
# Process raw data to build graph's edges (by user)
edges_user = []
for interaction in raw_data:
    source = interaction['user_screen_name']

    # quotes interaction
    if interaction['in_quote_username'].strip('-'):
        destination = interaction['in_quote_username']
        edges_user.append([source, destination, 'quote'])

    # replies interaction
    if interaction['in_reply_username'].strip('-'):
        destination = interaction['in_reply_username']
        edges_user.append([source, destination, 'reply'])

print(f"Generated edges: {len(edges_user)}")
# Out:
# Generated edges: 216

# %%
# Process raw data to build graph's edges (by text)
def find_interaction_on_id(id):
    for d in raw_data:
        if d['id'] == id:
            return d
    
edges_text = []
for interaction in raw_data:
    source = interaction['text']

    # quotes interaction
    try:
        if interaction['in_quote_id'].strip('-'):
            destination = find_interaction_on_id(interaction['in_quote_id'])['text']
            edges_text.append([source, destination, 'quote'])
    except:
        print(f'quoted parent not found!')

    # replies interaction
    try:
        if interaction['in_reply_id'].strip('-'):
            destination = find_interaction_on_id(interaction['in_reply_id'])['text']
            edges_text.append([source, destination, 'reply'])
    except:
        print(f'replied parent not found!')        

print(f"Generated edges: {len(edges_text)}")
# Out:
# quoted parent not found!
# quoted parent not found!
# quoted parent not found!
# quoted parent not found!
# quoted parent not found!
# quoted parent not found!
# Generated edges: 210

# %%
data = cudf.DataFrame(raw_data)
data.head()
# Out:
#                     id user_screen_name  user_followers_count  \
# 0  1828253940003283240    ardisatriawan                 69800
# 1  1828351087885328471    martintjandra                   364
# 2  1828254349610672324       ulanbatori                     3
# 3  1828276281395552310          hmadZak                   257
# 4  1828256055849296275    Abdillahh_Ali                    25
#
#    user_friends_count            user_created_at  user_status_count  \
# 0                2665  2010-07-25T03:31:53+00:00              12517
# 1                1333  2009-07-29T06:56:10+00:00              16212
# 2                  35  2024-07-11T00:59:17+00:00               3508
# 3                 768  2012-04-18T10:23:37+00:00              11131
# 4                 176  2021-10-29T07:52:24+00:00               2277
#
#    user_is_verified                                   user_description  \
# 0             False  Mulai males ngedit meme soang.\n\nResearch fel...
# 1             False      In conclusion, you’re not ChatGPT, unlike me.
# 2             False
# 3             False                   Berjalan adalah sebuah kebutuhan
# 4             False            Football, politics, and film enthusiast
#
#    user_media_count                                               text  ...  \
# 0               548  Media Singapura sudah mulai mencium gelagat an...  ...
# 1               506  @ardisatriawan Lagi rame gini bukannya berusah...  ...
# 2                60                  @ardisatriawan 🤣ok arya kamandanu  ...
# 3               302           @ardisatriawan Makin menarik ini mulyono  ...
# 4                19  @ardisatriawan Sebenarnya masalah gratifikasi ...  ...
#
#   is_retweeted  entities_hashtag entities_mentions in_quote_username  \
# 0        False                []                []
# 1        False                []  [#ardisatriawan]
# 2        False                []  [#ardisatriawan]
# 3        False                []  [#ardisatriawan]
# 4        False                []  [#ardisatriawan]
#
#   in_quote_id in_reply_username          in_reply_id media_urls  \
# 0           -                 -                    -         []
# 1           -     ardisatriawan  1828253940003283240         []
# 2           -     ardisatriawan  1828253940003283240         []
# 3           -     ardisatriawan  1828253940003283240         []
# 4           -     ardisatriawan  1828253940003283240         []
#
#                    created_at                  updated_at
# 0  2024-12-11T11:24:02.816215  2024-12-11T11:24:02.816218
# 1  2024-12-11T11:24:02.816581  2024-12-11T11:24:02.816582
# 2  2024-12-11T11:24:02.816639  2024-12-11T11:24:02.816640
# 3  2024-12-11T11:24:02.816678  2024-12-11T11:24:02.816679
# 4  2024-12-11T11:24:02.816712  2024-12-11T11:24:02.816712
#
# [5 rows x 25 columns]

# %%
data.rename({'id':'user_id'}, axis=1, inplace=True)
# Out:
#                  user_id user_screen_name  user_followers_count  \
# 0    1828253940003283240    ardisatriawan                 69800
# 1    1828351087885328471    martintjandra                   364
# 2    1828254349610672324       ulanbatori                     3
# 3    1828276281395552310          hmadZak                   257
# 4    1828256055849296275    Abdillahh_Ali                    25
# ..                   ...              ...                   ...
# 206  1828387932388167838        nandazman                   154
# 207  1828421953704861858  Ib27189947Arief                  1081
# 208  1828422249462034906         febul0us                   575
# 209  1828425752855093687     echanthought                   543
# 210  1828426913163182457         wichests                   811
#
#      user_friends_count            user_created_at  user_status_count  \
# 0                  2665  2010-07-25T03:31:53+00:00              12517
# 1                  1333  2009-07-29T06:56:10+00:00              16212
# 2                    35  2024-07-11T00:59:17+00:00               3508
# 3                   768  2012-04-18T10:23:37+00:00              11131
# 4                   176  2021-10-29T07:52:24+00:00               2277
# ..                  ...                        ...                ...
# 206                 175  2010-07-02T14:18:20+00:00               1473
# 207                6874  2020-08-04T12:49:41+00:00               1322
# 208                 432  2011-02-19T12:40:57+00:00               8900
# 209                 318  2012-03-15T08:58:44+00:00              25599
# 210                 946  2019-06-13T17:09:55+00:00             125516
#
#      user_is_verified                                   user_description  \
# 0               False  Mulai males ngedit meme soang.\n\nResearch fel...
# 1               False      In conclusion, you’re not ChatGPT, unlike me.
# 2               False
# 3               False                   Berjalan adalah sebuah kebutuhan
# 4               False            Football, politics, and film enthusiast
# ..                ...                                                ...
# 206             False                                        Equilibrium
# 207             False
# 208             False
# 209             False  ꒰ 🌻 ꒱ؘ ࿐ ࿔*:･ﾟ 𝓎𝑜𝓊𝓇 𝒻𝒶𝓋 𝓈𝓊𝓃𝒻𝓁𝑜𝓌𝑒𝓇𝓈 ๑ꕤꮺǂ       ...
# 210             False  Open jasa translate n pindahan https://t.co/hJ...
#
#      user_media_count                                               text  ...  \
# 0                 548  Media Singapura sudah mulai mencium gelagat an...  ...
# 1                 506  @ardisatriawan Lagi rame gini bukannya berusah...  ...
# 2                  60                  @ardisatriawan 🤣ok arya kamandanu  ...
# 3                 302           @ardisatriawan Makin menarik ini mulyono  ...
# 4                  19  @ardisatriawan Sebenarnya masalah gratifikasi ...  ...
# ..                ...                                                ...  ...
# 206               241           @ardisatriawan ieu rame din @dindariztia  ...
# 207                 1  @ardisatriawan Produk luar merajalela...menyog...  ...
# 208               427                    @ardisatriawan Manyala Erina ku  ...
# 209              1069        @ardisatriawan wah ramee wkwkwk @edmirablee  ...
# 210              4938  @ardisatriawan Yaowoh cuma gara gara ada mbak ...  ...
#
#     is_retweeted  entities_hashtag               entities_mentions  \
# 0          False                []                              []
# 1          False                []                [#ardisatriawan]
# 2          False                []                [#ardisatriawan]
# 3          False                []                [#ardisatriawan]
# 4          False                []                [#ardisatriawan]
# ..           ...               ...                             ...
# 206        False                []  [#ardisatriawan, #dindariztia]
# 207        False                []                [#ardisatriawan]
# 208        False                []                [#ardisatriawan]
# 209        False                []   [#ardisatriawan, #edmirablee]
# 210        False                []                [#ardisatriawan]
#
#     in_quote_username in_quote_id in_reply_username          in_reply_id  \
# 0                               -                 -                    -
# 1                               -     ardisatriawan  1828253940003283240
# 2                               -     ardisatriawan  1828253940003283240
# 3                               -     ardisatriawan  1828253940003283240
# 4                               -     ardisatriawan  1828253940003283240
# ..                ...         ...               ...                  ...
# 206                             -     ardisatriawan  1828253940003283240
# 207                             -     ardisatriawan  1828253940003283240
# 208                             -     ardisatriawan  1828253940003283240
# 209                             -     ardisatriawan  1828253940003283240
# 210                             -     ardisatriawan  1828253940003283240
#
#     media_urls                  created_at                  updated_at
# 0           []  2024-12-11T11:24:02.816215  2024-12-11T11:24:02.816218
# 1           []  2024-12-11T11:24:02.816581  2024-12-11T11:24:02.816582
# 2           []  2024-12-11T11:24:02.816639  2024-12-11T11:24:02.816640
# 3           []  2024-12-11T11:24:02.816678  2024-12-11T11:24:02.816679
# 4           []  2024-12-11T11:24:02.816712  2024-12-11T11:24:02.816712
# ..         ...                         ...                         ...
# 206         []  2024-12-11T11:24:02.898939  2024-12-11T11:24:02.898939
# 207         []  2024-12-11T11:24:02.898969  2024-12-11T11:24:02.898969
# 208         []  2024-12-11T11:24:02.898998  2024-12-11T11:24:02.898999
# 209         []  2024-12-11T11:24:02.899028  2024-12-11T11:24:02.899028
# 210         []  2024-12-11T11:24:02.899057  2024-12-11T11:24:02.899058
#
# [211 rows x 25 columns]

# %%
edges_user[:5]
# Out:
# [['martintjandra', 'ardisatriawan', 'reply'],
#  ['ulanbatori', 'ardisatriawan', 'reply'],
#  ['hmadZak', 'ardisatriawan', 'reply'],
#  ['Abdillahh_Ali', 'ardisatriawan', 'reply'],
#  ['PambinyaTaehyun', 'ardisatriawan', 'reply']]

# %% [markdown]
# ## Visualization by User Graph

# %%
# Build Graph
G = cugraph.Graph() 
G.from_cudf_edgelist(data, source='user_id', destination='in_reply_id')
edges = G.edges()

# %%
ITERATIONS=500
THETA=10.0

g1_layout = cugraph.layout.force_atlas2(G,
    max_iter=ITERATIONS,
    strong_gravity_mode=False,
    outbound_attraction_distribution=True,
    lin_log_mode=False,
    barnes_hut_optimize=True,
    barnes_hut_theta=THETA,
    verbose=False
)

# %%
g1_layout
# Out:
#               x           y               vertex
# 0      3.207886  161.607285  1828291290821243358
# 1     10.432313  198.799042  1828280282962895146
# 2    202.691391   74.519821  1828290174775894166
# 3    -89.473518  -28.572798  1828276445547733178
# 4     -0.031832    1.823857  1828267605850984611
# ..          ...         ...                  ...
# 207   -0.061973    2.693297  1828313339908497467
# 208   -0.033754    2.137071  1828263532900815172
# 209   -0.033486    2.165435  1828280340903010410
# 210   -0.029945    2.187370  1830491785069760942
# 211   -0.152978    3.520883  1828269539450331565
#
# [212 rows x 3 columns]

# %%
data.sample()
# Out:
#                 user_id user_screen_name  user_followers_count  \
# 77  1828417483310809502  AbdulWa52303403                  1785
#
#     user_friends_count            user_created_at  user_status_count  \
# 77                2852  2020-05-10T05:07:14+00:00               2807
#
#     user_is_verified user_description  user_media_count  \
# 77             False       apa adanya                32
#
#                                                  text  ... is_retweeted  \
# 77  @ardisatriawan Gak mungkin duit hasil jual mar...  ...        False
#
#     entities_hashtag entities_mentions in_quote_username in_quote_id  \
# 77                []  [#ardisatriawan]                             -
#
#    in_reply_username          in_reply_id media_urls  \
# 77     ardisatriawan  1828253940003283240         []
#
#                     created_at                  updated_at
# 77  2024-12-11T11:24:02.846934  2024-12-11T11:24:02.846934
#
# [1 rows x 25 columns]

# %%
final_df = g1_layout.merge(
    data[['user_id','in_reply_id','user_screen_name','in_reply_username','user_followers_count','user_friends_count']],
    left_on='vertex',
    right_on='user_id',
    suffixes=('', '_original')
)

# Check
final_df.head()
# Out:
#           x         y               vertex              user_id  \
# 0 -0.033754  2.137071  1828263532900815172  1828263532900815172
# 1 -0.033486  2.165435  1828280340903010410  1828280340903010410
# 2 -0.029945  2.187370  1830491785069760942  1830491785069760942
# 3 -0.152978  3.520883  1828269539450331565  1828269539450331565
# 4 -0.064587  2.724308  1828287097066922217  1828287097066922217
#
#            in_reply_id user_screen_name in_reply_username  \
# 0  1828253940003283240      retamialffn     ardisatriawan
# 1  1828253940003283240       naoireisha     ardisatriawan
# 2  1828253940003283240    dickysubhan22     ardisatriawan
# 3  1828253940003283240      kusmawan_11     ardisatriawan
# 4  1828253940003283240          ffinnnX     ardisatriawan
#
#    user_followers_count  user_friends_count
# 0                    84                 139
# 1                    23                 459
# 2                   135                 123
# 3                    52                 372
# 4                     7                  14

# %%
final_df.head()
# Out:
#           x         y               vertex              user_id  \
# 0 -0.033754  2.137071  1828263532900815172  1828263532900815172
# 1 -0.033486  2.165435  1828280340903010410  1828280340903010410
# 2 -0.029945  2.187370  1830491785069760942  1830491785069760942
# 3 -0.152978  3.520883  1828269539450331565  1828269539450331565
# 4 -0.064587  2.724308  1828287097066922217  1828287097066922217
#
#            in_reply_id user_screen_name in_reply_username  \
# 0  1828253940003283240      retamialffn     ardisatriawan
# 1  1828253940003283240       naoireisha     ardisatriawan
# 2  1828253940003283240    dickysubhan22     ardisatriawan
# 3  1828253940003283240      kusmawan_11     ardisatriawan
# 4  1828253940003283240          ffinnnX     ardisatriawan
#
#    user_followers_count  user_friends_count
# 0                    84                 139
# 1                    23                 459
# 2                   135                 123
# 3                    52                 372
# 4                     7                  14

# %%
edges.head()
# Out:
#                user_id          in_reply_id
# 0  1828265207438983544  1828253940003283240
# 1  1828265762538299889  1828253940003283240
# 2  1828266868957946362  1828253940003283240
# 3  1828431257132507408  1828253940003283240
# 4  1828273966009798991  1828253940003283240

# %%
# filter out non edges
numeric_columns = ['user_id', 'in_reply_id', 'user_followers_count', 'user_friends_count']

for col in numeric_columns:
    if col in final_df.columns:
        final_df[col] = cudf.to_numeric(final_df[col], errors='coerce')

# final_df['in_reply_id'] = cudf.to_numeric(final_df['in_reply_id'])
# final_df['in_reply_id']

# %%
final_df['user_id'] = cudf.to_numeric(final_df['user_id'])
final_df['in_reply_id'] = cudf.to_numeric(final_df['in_reply_id'])

edges['user_id'] = cudf.to_numeric(edges['user_id'])
edges['in_reply_id'] = cudf.to_numeric(edges['in_reply_id'])

# Check data types
print("Final_df dtypes:")
print(final_df[['user_id', 'in_reply_id']].dtypes)
print("\nEdges dtypes:")
print(edges[['user_id', 'in_reply_id']].dtypes)

cux_df = cuxfilter.DataFrame.load_graph((final_df, edges))
# Out:
# Final_df dtypes:
# user_id          int64
# in_reply_id    float64
# dtype: object
#
# Edges dtypes:
# user_id        int64
# in_reply_id    int64
# dtype: object

# %%
chart1 = cuxfilter.charts.graph(
          edge_source='user_id', edge_target='in_reply_id',
          edge_color_palette=['gray', 'black'],
      #     ode_pixel_shade_type='linear',
          edge_render_type='curved', #curved, direct
          edge_transparency=0.6, #0.1 - 0.9
          title='Sample Graph 1'
      )

d = cux_df.dashboard(
    [chart1],
    theme=cuxfilter.themes.rapids,
    title="Network Graph"
)

d.show(port=8090)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2a69320f-1f53-4f25-a1d7-56792bf33f0c'>
#   <div id="b7c0813f-fda1-466e-9975-eaf8a553e0ec" data-root-id="2a69320f-1f53-4f25-a1d7-56792bf33f0c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"aac4d5bb-a9d3-412e-ae84-2e552dacf468":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"2a69320f-1f53-4f25-a1d7-56792bf33f0c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"af94b8f3-fb0c-448d-b997-051d44038a7c","attributes":{"plot_id":"2a69320f-1f53-4f25-a1d7-56792bf33f0c","comm_id":"9dff0028de4f464da9eff29d550a5545","client_comm_id":"7836b8b14126466c910d57a77fc39366"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"aac4d5bb-a9d3-412e-ae84-2e552dacf468","roots":{"2a69320f-1f53-4f25-a1d7-56792bf33f0c":"b7c0813f-fda1-466e-9975-eaf8a553e0ec"},"root_ids":["2a69320f-1f53-4f25-a1d7-56792bf33f0c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.deck !== undefined) && ( root.deck !== undefined) && ( root.deck !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Dashboard running at port 8090
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/cuxfilter/dashboard.py:562, in DashBoard.show(self, notebook_url, port, threaded, service_proxy, sidebar_width, height, **kwargs)
#     561 try:
# --> 562     self.server = self._get_server(
#     563         panel=panel,
#     564         port=port,
#     565         websocket_origin=self._notebook_url.netloc,
#     566         show=False,
#     567         start=True,
#     568         threaded=threaded,
#     569         sidebar_width=sidebar_width,
#     570         height=height,
#     571         **kwargs,
#     572     )
#     573 except OSError:
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/cuxfilter/dashboard.py:414, in DashBoard._get_server(self, panel, port, websocket_origin, loop, show, start, **kwargs)
#     404 def _get_server(
#     405     self,
#     406     panel=None,
#    (...)
#     412     **kwargs,
#     413 ):
# --> 414     server = get_server(
#     415         panel=panel,
#     416         port=port,
#     417         websocket_origin=websocket_origin,
#     418         loop=loop,
#     419         show=show,
#     420         start=start,
#     421         title=self.title,
#     422         **kwargs,
#     423     )
#     424     server_document(websocket_origin, resources=None)
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/panel/io/server.py:1049, in get_server(panel, port, address, websocket_origin, loop, show, start, title, verbose, location, admin, static_dirs, basic_auth, oauth_provider, oauth_key, oauth_secret, oauth_redirect_uri, oauth_extra_params, oauth_error_template, cookie_secret, oauth_encryption_key, oauth_jwt_user, oauth_refresh_tokens, oauth_guest_endpoints, oauth_optional, login_endpoint, logout_endpoint, login_template, logout_template, session_history, liveness, warm, **kwargs)
#    1047 opts['cookie_secret'] = config.cookie_secret
# -> 1049 server = Server(apps, port=port, **opts)
#    1050 if verbose:
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/panel/io/server.py:291, in Server.__init__(self, *args, **kwargs)
#     290 def __init__(self, *args, **kwargs):
# --> 291     super().__init__(*args, **kwargs)
#     292     self._autoreload_stop_event = None
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/bokeh/server/server.py:430, in Server.__init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     429 else:
# --> 430     sockets, self._port = bind_sockets(opts.address, opts.port)
#     431     self._address = opts.address
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/bokeh/server/util.py:68, in bind_sockets(address, port)
#      49 ''' Bind a socket to a port on an address.
#      50
#      51 Args:
#    (...)
#      66
#      67 '''
# ---> 68 ss = netutil.bind_sockets(port=port or 0, address=address)
#      69 assert len(ss)
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/tornado/netutil.py:162, in bind_sockets(port, address, family, backlog, flags, reuse_port)
#     161 try:
# --> 162     sock.bind(sockaddr)
#     163 except OSError as e:
#
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 16
#       1 chart1 = cuxfilter.charts.graph(
#       2           edge_source='user_id', edge_target='in_reply_id',
#       3           edge_color_palette=['gray', 'black'],
#    (...)
#       7           title='Sample Graph 1'
#       8       )
#      10 d = cux_df.dashboard(
#      11     [chart1],
#      12     theme=cuxfilter.themes.rapids,
#      13     title="Network Graph"
#      14 )
# ---> 16 d.show(port=8090)
#
# File ~/miniconda3/envs/sna-playground/lib/python3.11/site-packages/cuxfilter/dashboard.py:574, in DashBoard.show(self, notebook_url, port, threaded, service_proxy, sidebar_width, height, **kwargs)
#     562     self.server = self._get_server(
#     563         panel=panel,
#     564         port=port,
#    (...)
#     571         **kwargs,
#     572     )
#     573 except OSError:
# --> 574     self.server.stop()
#     575     self.server = self._get_server(
#     576         panel=panel,
#     577         port=port,
#    (...)
#     582         **kwargs,
#     583     )
#     584 self._current_server_type = "show"
#
# AttributeError: 'NoneType' object has no attribute 'stop'
